# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadiya-safeer11/phonetics-vowel-counter/blob/main/vowel_counter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

def count_vowels(text):
    vowels = "aeiou"
    text = text.lower()
    return {v: text.count(v) for v in vowels}

def plot_vowel_counts(vowel_counts):
    plt.bar(vowel_counts.keys(), vowel_counts.values(), color='skyblue')
    plt.title("Vowel Frequency in Text")
    plt.xlabel("Vowels")
    plt.ylabel("Count")
    plt.show()

# Example run
text = "This is a GitHub + Colab test for vowels."
counts = count_vowels(text)
print("Vowel Counts:", counts)
plot_vowel_counts(counts)
# Out:
# Vowel Counts: {'a': 2, 'e': 2, 'i': 3, 'o': 3, 'u': 1}
